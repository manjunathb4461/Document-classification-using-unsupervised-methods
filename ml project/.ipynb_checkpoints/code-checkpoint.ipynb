# %%
import csv
import os
#from textblob import TextBlob
import nltk
#import spacy
#nlp = spacy.load("en")

#import Valence
#Valence.download_depechemood()

import sklearn

from nltk.corpus import stopwords
STOPWORDS = list(set(stopwords.words('english')))
punctuations = ['\n', "\'", '\"', ',', '.', ')', '(', "]", "[", '-']+[str(i) for i in range(10)]

import numpy as np
from sklearn.decomposition import TruncatedSVD

from gensim.models import Word2Vec

classes = ["business", "entertainment", "politics", "sport", "tech"]
lemma = nltk.stem.WordNetLemmatizer()
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
#reading dataset
data = []
for c in classes:
    for File in os.listdir("data/"+c):
        s = "".join(i if i not in punctuations else ' ' for i in open("data/"+c+'/'+File).read())
        s = " ".join(lemma.lemmatize(i) for i in s.split() if i not in STOPWORDS)
        data.append(s)
        
print("total data length : ", len(data))
# Out:
# total data length :  1500

# %%
maxx, minn = 0, 100000
for i in data:
    maxx = max(maxx, len(i.split()))
    minn = min(minn, len(i.split()))
    
print("max and min number of words across documents : ", maxx, minn)
# Out:
# max and min number of words across documents :  2437 69

# %%
def mod_kmeans(ctrs, X):
    ctrs = 300 if ctrs>300 else ctrs
    maxx, maxx_ctr, n_labels = 0, 0, []
    for ctr in range(ctrs):
        init_ctrs = np.array([X[0+ctr], X[300+ctr], X[600+ctr], X[900+ctr], X[1200+ctr]])
        kmeans = KMeans(n_clusters=5, n_init=1, init=init_ctrs).fit(X)
        actual_ctrs = np.array([cc for cc, _ in enumerate(classes) for _ in range(300)])
        accuracy = np.sum(kmeans.labels_ == actual_ctrs) / 1500
        
        if accuracy > maxx:
            maxx = accuracy
            maxx_ctr = ctr
            n_labels = kmeans.labels_
    
    return maxx_ctr, maxx, n_labels

# %%
vectorizer = sklearn.feature_extraction.text.TfidfVectorizer(stop_words=STOPWORDS, max_features=200)

# %%
#tf-idf conversion of train data
tfidf_matrix = vectorizer.fit_transform(data)
X = tfidf_matrix.todense().tolist()
#to_minus = len(X[0])     #padding the data(pre-processing step)
#for dd, d in enumerate(X):
#    X[dd] += [0] * (len_corpus-to_minus)
print("shape of tf-ifd : ", len(X), len(X[0]))
# Out:
# shape of tf-ifd :  1500 200

# %%
n_iters = 10
maxx_ctr, maxx, n_labels = mod_kmeans(n_iters, X)
print("maxx accuracy achieved with initial centre {} accuracy : {}".format(maxx_ctr, maxx))
# Out:
# maxx accuracy achieved with initial centre 1 accuracy : 0.8673333333333333

# %%
pca = PCA(n_components=2).fit_transform(X)
plot = []
markers = ['o', 'x', '+', '<', 'd']
colors = ['red', 'green', 'blue', 'pink', 'yellow']

for cls in range(5):
    for ii, i in enumerate(n_labels):
        if i == cls:
            plot.append([pca[ii][0], pca[ii][1], colors[cls], markers[cls]])
    
plot = list(zip(*plot))
plt.scatter(plot[0], plot[1], c=plot[2], alpha=0.7)
plt.plot()
plt.savefig("kmeans.png", dpi=300)

# %%
clf = sklearn.svm.LinearSVC()
clf.fit(X, [c for c in classes for _ in range(300)])
print("accuracy : ", clf.score(X, [c for c in classes for _ in range(300)]))
# Out:
# accuracy :  0.982

# %%
from scipy.cluster.hierarchy import ward, dendrogram
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt

dist = 1 - cosine_similarity(tfidf_matrix)
linkage_matrix = ward(dist) #define the linkage_matrix using ward clustering pre-computed distances

fig, ax = plt.subplots(figsize=(15, 20)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=["-"*cc for cc,_ in enumerate(classes) for _ in range(300)])

plt.tick_params(\
    axis= 'x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

#uncomment below to save figure
plt.savefig('TF-IDF_ward_clusters.png', dpi=300) #save figure as ward_clusters
# Out:
# /home/manjunath/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
from sklearn.cluster import DBSCAN
import numpy as np

for e in np.arange(0, 1.5, 0.01):
    clustering = DBSCAN(eps=e, min_samples=100, algorithm="brute").fit(X)
    actual_ctrs = np.array([cc for cc, _ in enumerate(classes) for _ in range(300)])
    #print(len(set(clustering.labels_)))
    labels = clustering.labels_
    core_samples = np.zeros_like(actual_ctrs, dtype = int)
    core_samples[clustering.core_sample_indices_] = True
    accuracy = np.sum(clustering.labels_ == actual_ctrs) / 1500
    print(accuracy, e)
# Out:
# 0.2 0.0
# 0.2 0.01
# 0.2 0.02
# 0.2 0.03
# 0.2 0.04
# 0.2 0.05
# 0.2 0.06
# 0.2 0.07
# 0.2 0.08
# 0.2 0.09
# 0.2 0.1
# 0.2 0.11
# 0.2 0.12
# 0.2 0.13
# 0.2 0.14
# 0.2 0.15
# 0.2 0.16
# 0.2 0.17
# 0.2 0.18
# 0.2 0.19
# 0.2 0.2
# 0.2 0.21
# 0.2 0.22
# 0.2 0.23
# 0.2 0.24
# 0.2 0.25
# 0.2 0.26
# 0.2 0.27
# 0.2 0.28
# 0.2 0.29
# 0.2 0.3
# 0.2 0.31
# 0.2 0.32
# 0.2 0.33
# 0.2 0.34
# 0.2 0.35000000000000003
# 0.2 0.36
# 0.2 0.37
# 0.2 0.38
# 0.2 0.39
# 0.2 0.4
# 0.2 0.41000000000000003
# 0.2 0.42
# 0.2 0.43
# 0.2 0.44
# 0.2 0.45
# 0.2 0.46
# 0.2 0.47000000000000003
# 0.2 0.48
# 0.2 0.49
# 0.2 0.5
# 0.2 0.51
# 0.2 0.52
# 0.2 0.53
# 0.2 0.54
# 0.2 0.55
# 0.2 0.56
# 0.2 0.5700000000000001
# 0.2 0.58
# 0.2 0.59
# 0.2 0.6
# 0.2 0.61
# 0.2 0.62
# 0.2 0.63
# 0.2 0.64
# 0.2 0.65
# 0.2 0.66
# 0.2 0.67
# 0.2 0.68
# 0.2 0.6900000000000001
# 0.2 0.7000000000000001
# 0.2 0.71
# 0.2 0.72
# 0.2 0.73
# 0.2 0.74
# 0.2 0.75
# 0.2 0.76
# 0.2 0.77
# 0.2 0.78
# 0.2 0.79
# 0.2 0.8
# 0.2 0.81
# 0.2 0.8200000000000001
# 0.2 0.8300000000000001
# 0.2 0.84
# 0.2 0.85
# 0.2 0.86
# 0.2 0.87
# 0.2 0.88
# 0.2 0.89
# 0.2 0.9
# 0.2 0.91
# 0.2 0.92
# 0.2 0.93
# 0.2 0.9400000000000001
# 0.2 0.9500000000000001
# 0.2 0.96
# 0.2 0.97
# 0.2 0.98
# 0.2 0.99
# 0.2 1.0
# 0.2 1.01
# 0.2 1.02
# 0.2 1.03
# 0.2 1.04
# 0.2 1.05
# 0.2 1.06
# 0.2 1.07
# 0.2 1.08
# 0.2 1.09
# 0.2 1.1
# 0.2 1.11
# 0.2 1.12
# 0.2 1.1300000000000001
# 0.2 1.1400000000000001
# 0.2 1.1500000000000001
# 0.2 1.16
# 0.2 1.17
# 0.2 1.18
# 0.2 1.19
# 0.2 1.2
# 0.2 1.21
# 0.2 1.22
# 0.2 1.23
# 0.2 1.24
# 0.2 1.25
# 0.2 1.26
# 0.2 1.27
# 0.2 1.28
# 0.2 1.29
# 0.2 1.3
# 0.2 1.31
# 0.2 1.32
# 0.2 1.33
# 0.2 1.34
# 0.2 1.35
# 0.2 1.36
# 0.2 1.37
# 0.2 1.3800000000000001
# 0.2 1.3900000000000001
# 0.2 1.4000000000000001
# 0.2 1.41
# 0.2 1.42
# 0.2 1.43
# 0.2 1.44
# 0.2 1.45
# 0.2 1.46
# 0.2 1.47
# 0.2 1.48
# 0.2 1.49

# %%
#preparing the word2vec model
dim = 200
model = Word2Vec([i.split() for i in data], min_count=1, size=dim)

# %%
#feature extraction
X = []
for i in data:
    temp, c = [], 0
    for word in i.split():
        c += 1
        temp.append(model.wv.__getitem__(word).tolist())
    X.append([i/c for i in [sum(x) for x in zip(*temp)]])

print("features shape : ", len(X), len(X[0]))
# Out:
# features shape :  1500 200

# %%
n_iters = 10
maxx_ctr, maxx, n_labels = mod_kmeans(n_iters, X)
print("maxx accuracy achieved with initial centre {} accuracy : {}".format(maxx_ctr, maxx))
# Out:
# maxx accuracy achieved with initial centre 2 accuracy : 0.4046666666666667

# %%
clf = sklearn.svm.LinearSVC()
clf.fit(X, [c for c in classes for _ in range(300)])
print("accuracy : ", clf.score(X, [c for c in classes for _ in range(300)]))
# Out:
# accuracy :  0.672

# %%
from scipy.cluster.hierarchy import ward, dendrogram
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt

dist = 1 - cosine_similarity(tfidf_matrix)
linkage_matrix = ward(dist) #define the linkage_matrix using ward clustering pre-computed distances

fig, ax = plt.subplots(figsize=(15, 20)) # set size
ax = dendrogram(linkage_matrix, orientation="right", labels=[str(cc)*4 for cc,_ in enumerate(classes) for _ in range(300)])

plt.tick_params(\
    axis= 'x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',         # ticks along the top edge are off
    labelbottom='off')

plt.tight_layout() #show plot with tight layout

#uncomment below to save figure
plt.savefig('Word2Vec_ward_clusters.png', dpi=300) #save figure as ward_clusters
# Out:
# /home/manjunath/anaconda3/lib/python3.7/site-packages/matplotlib/cbook/__init__.py:424: MatplotlibDeprecationWarning:
# Passing one of 'on', 'true', 'off', 'false' as a boolean is deprecated; use an actual boolean (True/False) instead.
#   warn_deprecated("2.2", "Passing one of 'on', 'true', 'off', 'false' as a "

# %%
from sklearn.cluster import DBSCAN
import numpy as np

for e in np.arange(0, 1.5, 0.01):
    clustering = DBSCAN(eps=1.2, min_samples=e, algorithm="brute").fit(X)
    actual_ctrs = np.array([cc for cc, _ in enumerate(classes) for _ in range(300)])
    #print(len(set(clustering.labels_)))
    labels = clustering.labels_
    core_samples = np.zeros_like(actual_ctrs, dtype = int)
    core_samples[clustering.core_sample_indices_] = True
    accuracy = np.sum(clustering.labels_ == actual_ctrs) / 1500
    print("for eps : {}, acheived accuracy is : {}".format(accuracy, e))
# Out:
# for eps : 0.2, acheived accuracy is : 0.0
# for eps : 0.2, acheived accuracy is : 0.01
# for eps : 0.2, acheived accuracy is : 0.02
# for eps : 0.2, acheived accuracy is : 0.03
# for eps : 0.2, acheived accuracy is : 0.04
# for eps : 0.2, acheived accuracy is : 0.05
# for eps : 0.2, acheived accuracy is : 0.06
# for eps : 0.2, acheived accuracy is : 0.07
# for eps : 0.2, acheived accuracy is : 0.08
# for eps : 0.2, acheived accuracy is : 0.09
# for eps : 0.2, acheived accuracy is : 0.1
# for eps : 0.2, acheived accuracy is : 0.11
# for eps : 0.2, acheived accuracy is : 0.12
# for eps : 0.2, acheived accuracy is : 0.13
# for eps : 0.2, acheived accuracy is : 0.14
# for eps : 0.2, acheived accuracy is : 0.15
# for eps : 0.2, acheived accuracy is : 0.16
# for eps : 0.2, acheived accuracy is : 0.17
# for eps : 0.2, acheived accuracy is : 0.18
# for eps : 0.2, acheived accuracy is : 0.19
# for eps : 0.2, acheived accuracy is : 0.2
# for eps : 0.2, acheived accuracy is : 0.21
# for eps : 0.2, acheived accuracy is : 0.22
# for eps : 0.2, acheived accuracy is : 0.23
# for eps : 0.2, acheived accuracy is : 0.24
# for eps : 0.2, acheived accuracy is : 0.25
# for eps : 0.2, acheived accuracy is : 0.26
# for eps : 0.2, acheived accuracy is : 0.27
# for eps : 0.2, acheived accuracy is : 0.28
# for eps : 0.2, acheived accuracy is : 0.29
# for eps : 0.2, acheived accuracy is : 0.3
# for eps : 0.2, acheived accuracy is : 0.31
# for eps : 0.2, acheived accuracy is : 0.32
# for eps : 0.2, acheived accuracy is : 0.33
# for eps : 0.2, acheived accuracy is : 0.34
# for eps : 0.2, acheived accuracy is : 0.35000000000000003
# for eps : 0.2, acheived accuracy is : 0.36
# for eps : 0.2, acheived accuracy is : 0.37
# for eps : 0.2, acheived accuracy is : 0.38
# for eps : 0.2, acheived accuracy is : 0.39
# for eps : 0.2, acheived accuracy is : 0.4
# for eps : 0.2, acheived accuracy is : 0.41000000000000003
# for eps : 0.2, acheived accuracy is : 0.42
# for eps : 0.2, acheived accuracy is : 0.43
# for eps : 0.2, acheived accuracy is : 0.44
# for eps : 0.2, acheived accuracy is : 0.45
# for eps : 0.2, acheived accuracy is : 0.46
# for eps : 0.2, acheived accuracy is : 0.47000000000000003
# for eps : 0.2, acheived accuracy is : 0.48
# for eps : 0.2, acheived accuracy is : 0.49
# for eps : 0.2, acheived accuracy is : 0.5
# for eps : 0.2, acheived accuracy is : 0.51
# for eps : 0.2, acheived accuracy is : 0.52
# for eps : 0.2, acheived accuracy is : 0.53
# for eps : 0.2, acheived accuracy is : 0.54
# for eps : 0.2, acheived accuracy is : 0.55
# for eps : 0.2, acheived accuracy is : 0.56
# for eps : 0.2, acheived accuracy is : 0.5700000000000001
# for eps : 0.2, acheived accuracy is : 0.58
# for eps : 0.2, acheived accuracy is : 0.59
# for eps : 0.2, acheived accuracy is : 0.6
# for eps : 0.2, acheived accuracy is : 0.61
# for eps : 0.2, acheived accuracy is : 0.62
# for eps : 0.2, acheived accuracy is : 0.63
# for eps : 0.2, acheived accuracy is : 0.64
# for eps : 0.2, acheived accuracy is : 0.65
# for eps : 0.2, acheived accuracy is : 0.66
# for eps : 0.2, acheived accuracy is : 0.67
# for eps : 0.2, acheived accuracy is : 0.68
# for eps : 0.2, acheived accuracy is : 0.6900000000000001
# for eps : 0.2, acheived accuracy is : 0.7000000000000001
# for eps : 0.2, acheived accuracy is : 0.71
# for eps : 0.2, acheived accuracy is : 0.72
# for eps : 0.2, acheived accuracy is : 0.73
# for eps : 0.2, acheived accuracy is : 0.74
# for eps : 0.2, acheived accuracy is : 0.75
# for eps : 0.2, acheived accuracy is : 0.76
# for eps : 0.2, acheived accuracy is : 0.77
# for eps : 0.2, acheived accuracy is : 0.78
# for eps : 0.2, acheived accuracy is : 0.79
# for eps : 0.2, acheived accuracy is : 0.8
# for eps : 0.2, acheived accuracy is : 0.81
# for eps : 0.2, acheived accuracy is : 0.8200000000000001
# for eps : 0.2, acheived accuracy is : 0.8300000000000001
# for eps : 0.2, acheived accuracy is : 0.84
# for eps : 0.2, acheived accuracy is : 0.85
# for eps : 0.2, acheived accuracy is : 0.86
# for eps : 0.2, acheived accuracy is : 0.87
# for eps : 0.2, acheived accuracy is : 0.88
# for eps : 0.2, acheived accuracy is : 0.89
# for eps : 0.2, acheived accuracy is : 0.9
# for eps : 0.2, acheived accuracy is : 0.91
# for eps : 0.2, acheived accuracy is : 0.92
# for eps : 0.2, acheived accuracy is : 0.93
# for eps : 0.2, acheived accuracy is : 0.9400000000000001
# for eps : 0.2, acheived accuracy is : 0.9500000000000001
# for eps : 0.2, acheived accuracy is : 0.96
# for eps : 0.2, acheived accuracy is : 0.97
# for eps : 0.2, acheived accuracy is : 0.98
# for eps : 0.2, acheived accuracy is : 0.99
# for eps : 0.2, acheived accuracy is : 1.0
# for eps : 0.2, acheived accuracy is : 1.01
# for eps : 0.2, acheived accuracy is : 1.02
# for eps : 0.2, acheived accuracy is : 1.03
# for eps : 0.2, acheived accuracy is : 1.04
# for eps : 0.2, acheived accuracy is : 1.05
# for eps : 0.2, acheived accuracy is : 1.06
# for eps : 0.2, acheived accuracy is : 1.07
# for eps : 0.2, acheived accuracy is : 1.08
# for eps : 0.2, acheived accuracy is : 1.09
# for eps : 0.2, acheived accuracy is : 1.1
# for eps : 0.2, acheived accuracy is : 1.11
# for eps : 0.2, acheived accuracy is : 1.12
# for eps : 0.2, acheived accuracy is : 1.1300000000000001
# for eps : 0.2, acheived accuracy is : 1.1400000000000001
# for eps : 0.2, acheived accuracy is : 1.1500000000000001
# for eps : 0.2, acheived accuracy is : 1.16
# for eps : 0.2, acheived accuracy is : 1.17
# for eps : 0.2, acheived accuracy is : 1.18
# for eps : 0.2, acheived accuracy is : 1.19
# for eps : 0.2, acheived accuracy is : 1.2
# for eps : 0.2, acheived accuracy is : 1.21
# for eps : 0.2, acheived accuracy is : 1.22
# for eps : 0.2, acheived accuracy is : 1.23
# for eps : 0.2, acheived accuracy is : 1.24
# for eps : 0.2, acheived accuracy is : 1.25
# for eps : 0.2, acheived accuracy is : 1.26
# for eps : 0.2, acheived accuracy is : 1.27
# for eps : 0.2, acheived accuracy is : 1.28
# for eps : 0.2, acheived accuracy is : 1.29
# for eps : 0.2, acheived accuracy is : 1.3
# for eps : 0.2, acheived accuracy is : 1.31
# for eps : 0.2, acheived accuracy is : 1.32
# for eps : 0.2, acheived accuracy is : 1.33
# for eps : 0.2, acheived accuracy is : 1.34
# for eps : 0.2, acheived accuracy is : 1.35
# for eps : 0.2, acheived accuracy is : 1.36
# for eps : 0.2, acheived accuracy is : 1.37
# for eps : 0.2, acheived accuracy is : 1.3800000000000001
# for eps : 0.2, acheived accuracy is : 1.3900000000000001
# for eps : 0.2, acheived accuracy is : 1.4000000000000001
# for eps : 0.2, acheived accuracy is : 1.41
# for eps : 0.2, acheived accuracy is : 1.42
# for eps : 0.2, acheived accuracy is : 1.43
# for eps : 0.2, acheived accuracy is : 1.44
# for eps : 0.2, acheived accuracy is : 1.45
# for eps : 0.2, acheived accuracy is : 1.46
# for eps : 0.2, acheived accuracy is : 1.47
# for eps : 0.2, acheived accuracy is : 1.48
# for eps : 0.2, acheived accuracy is : 1.49
